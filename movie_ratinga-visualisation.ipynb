# %%
import pandas as pd

# %%
movies=pd.read_csv(r'C:\Users\eknath.LAPTOP-BK5NENJ9\Downloads\4th,5th\4th,5th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
len(movies)
# Out:
# 559

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['film','genre','rotten_tomatoes_rating','audience_rating','budget','year']

# %%
movies.columns
# Out:
# Index(['film', 'genre', 'rotten_tomatoes_rating', 'audience_rating', 'budget',
#        'year'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   film                    559 non-null    object
#  1   genre                   559 non-null    object
#  2   rotten_tomatoes_rating  559 non-null    int64
#  3   audience_rating         559 non-null    int64
#  4   budget                  559 non-null    int64
#  5   year                    559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        rotten_tomatoes_rating  audience_rating      budget         year
# count              559.000000       559.000000  559.000000   559.000000
# mean                47.309481        58.744186   50.236136  2009.152057
# std                 26.413091        16.826887   48.731817     1.362632
# min                  0.000000         0.000000    0.000000  2007.000000
# 25%                 25.000000        47.000000   20.000000  2008.000000
# 50%                 46.000000        58.000000   35.000000  2009.000000
# 75%                 70.000000        72.000000   65.000000  2010.000000
# max                 97.000000        96.000000  300.000000  2011.000000

# %%
movies['film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: film, Length: 559, dtype: object

# %%
movies.film=movies.film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   film                    559 non-null    category
#  1   genre                   559 non-null    object
#  2   rotten_tomatoes_rating  559 non-null    int64
#  3   audience_rating         559 non-null    int64
#  4   budget                  559 non-null    int64
#  5   year                    559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.genre=movies.genre.astype('category')
movies.year=movies.year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   film                    559 non-null    category
#  1   genre                   559 non-null    category
#  2   rotten_tomatoes_rating  559 non-null    int64
#  3   audience_rating         559 non-null    int64
#  4   budget                  559 non-null    int64
#  5   year                    559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies.describe()
# Out:
#        rotten_tomatoes_rating  audience_rating      budget
# count              559.000000       559.000000  559.000000
# mean                47.309481        58.744186   50.236136
# std                 26.413091        16.826887   48.731817
# min                  0.000000         0.000000    0.000000
# 25%                 25.000000        47.000000   20.000000
# 50%                 46.000000        58.000000   35.000000
# 75%                 70.000000        72.000000   65.000000
# max                 97.000000        96.000000  300.000000

# %%
movies.genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=movies,x='rotten_tomatoes_rating',y='audience_rating')

# %%
j=sns.jointplot(data=movies,x='rotten_tomatoes_rating',y='audience_rating',kind='hex')

# %%
m1=sns.distplot(movies.audience_rating)

# %%
sns.set_style('darkgrid')

# %%
m2=sns.distplot(movies.audience_rating,bins=15)

# %%
n1=plt.hist(movies.audience_rating,bins=15)

# %%
sns.set_style('white')
n2=plt.hist(movies.audience_rating,bins=20)

# %%
n3=plt.hist(movies.rotten_tomatoes_rating,bins=20)

# %%
plt.hist(movies.budget)
plt.show()

# %%
plt.hist(movies[movies.genre=='Drama'].budget)
plt.show()

# %%
movies.head()
# Out:
#                     film      genre  rotten_tomatoes_rating  audience_rating  \
# 0  (500) Days of Summer      Comedy                      87               81
# 1            10,000 B.C.  Adventure                       9               44
# 2             12 Rounds      Action                      30               52
# 3              127 Hours  Adventure                      93               84
# 4              17 Again      Comedy                      55               70
#
#    budget  year
# 0       8  2009
# 1     105  2008
# 2      20  2009
# 3      18  2010
# 4      20  2009

# %%
movies.genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(movies[movies.genre=='Action'].budget,bins=20,label='Action')
plt.hist(movies[movies.genre=='Thriller'].budget,bins=20,label='thriller')
plt.hist(movies[movies.genre=='Drama'].budget,bins=20,label='Drama')
plt.legend()
plt.show()

# %%
labels=['Action','Drama','Thriller','Comedy']
plt.hist([movies[movies.genre == 'Action'].budget,\
          movies[movies.genre == 'Drama'].budget, \
          movies[movies.genre == 'Thriller'].budget, \
          movies[movies.genre == 'Comedy'].budget],
         bins = 20, stacked = True)
plt.legend(labels=labels)
plt.show()

# %%
for gen in movies.genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1=sns.lmplot(data=movies,x='rotten_tomatoes_rating',y='audience_rating',fit_reg=False)

# %%
vis1=sns.lmplot(data=movies,x='rotten_tomatoes_rating',y='audience_rating',fit_reg=True)

# %%
vis1 = sns.lmplot(data=movies, x='rotten_tomatoes_rating', y='audience_rating',\
                 fit_reg=False, hue = 'genre')

# %%
vis1 = sns.lmplot(data=movies, x='rotten_tomatoes_rating', y='audience_rating',fit_reg=False, hue = 'genre', size = 10,aspect=1)

# %%
k1=sns.kdeplot(movies.rotten_tomatoes_rating,movies.audience_rating)

# %%
k1 = sns.kdeplot(movies.rotten_tomatoes_rating,movies.audience_rating,shade = True,shade_lowest=False,cmap='Reds')

# %%
k2 = sns.kdeplot(movies.rotten_tomatoes_rating,movies.audience_rating,shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.budget,movies.audience_rating,shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(movies.budget,movies.audience_rating)

# %%
k2=sns.kdeplot(movies.budget,movies.rotten_tomatoes_rating)

# %%
f,ax=plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.budget,movies.audience_rating,ax=ax[0])
k2=sns.kdeplot(movies.budget,movies.rotten_tomatoes_rating,ax=ax[1])

# %%
w=sns.boxplot(x='genre',y='rotten_tomatoes_rating',data=movies)

# %%
z=sns.violinplot(x='genre',y='rotten_tomatoes_rating',data=movies)

# %%
w1=sns.boxplot(data=movies[movies.genre=='Drama'],x='year',y='rotten_tomatoes_rating')

# %%
z2=sns.violinplot(data=movies[movies.genre=='Drama'],x='year',y='rotten_tomatoes_rating')

# %%
g=sns.FacetGrid(data=movies,row='genre',col='year',hue='genre')

# %%
plt.scatter(movies.rotten_tomatoes_rating,movies.audience_rating)

# %%
g=sns.FacetGrid(data=movies,row='genre',col='year',hue='genre')
g=g.map(plt.scatter,'rotten_tomatoes_rating','audience_rating')

# %%
g=sns.FacetGrid(data=movies,row='genre',col='year')
g=g.map(plt.hist,'budget')

# %%
g=sns.FacetGrid(data=movies,row='genre',col='year',hue='genre')
kw=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'rotten_tomatoes_rating','audience_rating')

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(movies.budget,movies.audience_rating,ax=axes[0,0])
k2 = sns.kdeplot(movies.budget,movies.rotten_tomatoes_rating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.genre=='Drama'], x='year', y = 'rotten_tomatoes_rating', ax=axes[1,0])

k4 = sns.kdeplot(movies.rotten_tomatoes_rating,movies.audience_rating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(movies.rotten_tomatoes_rating, movies.audience_rating,cmap='Reds',ax = axes[1,1])

plt.show()
